# %% [markdown]
# # AO3
# René Alejandro González Velázquez
#
# Ingenieria Civil
#
# 752235
#
# 28/08/2024

# %% [markdown]
# **Resuelve los siguientes ejercicios:**

# %% [markdown]
# 1. Utiliza sympy y encuentra los valores de las incógnitas que hagan que los siguientes sistemas de ecuaciones sean verdaderos:
#
# ![image-e5aa4b19-2811-4878-a933-dc446834ff37.png](attachment:82e10c16-be26-4dcf-8058-cc81366e630d.png)
#
# ![image-091d37fb-e5ef-4bd3-982a-57c520e12d30.png](attachment:014c86fe-5c2c-44aa-813e-b5945094aefb.png)
#
# ![image-2d11219e-e5e6-4b8b-b8cb-c957da27c9f5.png](attachment:fccc298f-6bff-4012-b444-0e208f1f11b7.png)
#
# ![image-f8a00543-0fbf-42e1-bc55-de44af661639.png](attachment:90eff7ec-8e9c-4ab1-9c59-71da3219c102.png)
#
# 2. Encuentra los puntos críticos usando cálculo diferencial, decide si son máximos o mínimos usando el criterio de la segunda derivada, y grafica para decidir se son óptimos locales o globales:
#
# ![image-fa82a659-9c8b-4a52-b7f3-1552500daa20.png](attachment:c8810ece-4018-4e48-b435-59086a3ea3e2.png)
#
# ![image-6e766c90-0aec-4f32-9d59-9b33cd367616.png](attachment:c5da7727-0240-488e-80f5-4f6846bd0018.png)
#
# ![image-622a3e05-535c-430c-8123-a290107db020.png](attachment:a23d4e46-8d20-45a5-b73b-59894835922b.png)
#
# ![image-7c2af2d8-b72a-44b9-9eb0-6a46a1a78818.png](attachment:67a2943b-71e9-4a1a-ae06-194712b8dc62.png)
#
# Puntos a considerar:
# * Las ecuaciones deben estar transcritas en Markdown con el formato correcto.
# * Los puntos críticos en las gráficas deben estar marcados.

# %% [markdown]
# ### Ejercicio 1
# ![image-e5aa4b19-2811-4878-a933-dc446834ff37.png](attachment:362aafaa-0e41-46f2-b15c-eac5213ba9be.png)

# %%
import sympy as sp
x = sp.var('x')
y = sp.var('y')
eq1 = x + y - 10
eq2 = x - y - 2
solve = sp.solve((eq1, eq2), (x, y))
solve
# Out:
# {x: 6, y: 4}

# %% [markdown]
# $\frac{3x-2y}{3} + 4y = \frac{13}{3}$
#
# $\frac{2(-2y+x)}{3} - \frac{3x}{2} = -\frac{13}{6}$

# %%
x = sp.var("x") 
y = sp.var("y")
eq1 = (3*x - 2*y)/3 + 4*y - 13/3
eq2 = (2*(-2*y + x))/3 - (3*x)/2 + 13/6

solve = sp.solve((eq1, eq2), (x, y))
solve
# Out:
# {x: 1.00000000000000, y: 1.00000000000000}

# %% [markdown]
# ![image-2d11219e-e5e6-4b8b-b8cb-c957da27c9f5.png](attachment:e9974476-d306-4f95-a4fb-5d0befe821e6.png)

# %%
x = sp.var("x")
y = sp.var("y")
eq1 = x**2 - 2*y - 16
eq2 = x - y - 3

solve = sp.solve((eq1, eq2), (x, y))
solve
# Out:
# [(1 - sqrt(11), -sqrt(11) - 2), (1 + sqrt(11), -2 + sqrt(11))]

# %% [markdown]
# ![image-f8a00543-0fbf-42e1-bc55-de44af661639.png](attachment:60861e1d-8c62-4f34-bf51-abc37e915b18.png)

# %%
x = sp.var("x")
y = sp.var("y")
z = sp.var("z")
eq1 = x + y - z - 10
eq2 = x - y - 2
eq3 = y + z + 2

solve = sp.solve((eq1, eq2, eq3), (x, y, z))
solve
# Out:
# {x: 4, y: 2, z: -4}

# %% [markdown]
# ![image-fa82a659-9c8b-4a52-b7f3-1552500daa20.png](attachment:3a3d2e76-37ca-4d1a-96dc-9a1be73c1863.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
a = -6
b = 113
c = 1235

x = np.linspace(0, 20, 100)
fx= c + b * x + a * x**2
critico = b / (2 * -a)
f_x = -2 * a
if f_x > 0:
    z = 'min'
elif f_x < 0:
    z = 'max'
else:
    z = "No 
    
ycritico = c + b * critico + a * critico**2
print(f"Punto crítico: {critico}")
print(f"Segunda derivada en el punto crítico: {f_x}")
print(f"Clasificación del punto crítico: {z}")
plt.figure(figsize=(8, 6))
plt.plot(x, fx, label="f(x) = 1235 + 113x - 6x^2")
plt.plot(critico, ycritico)
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Gráfica de la función y punto crítico")
plt.legend()
plt.grid()
plt.show()
# Out:
# Punto crítico: 9.416666666666666
# Segunda derivada en el punto crítico: 12
# Clasificación del punto crítico: mínimo local

# %% [markdown]
# ![image-6e766c90-0aec-4f32-9d59-9b33cd367616.png](attachment:1d54ba27-59cb-4e1e-8e90-f0fee29a7ccf.png)

# %% [markdown]
# ![image-622a3e05-535c-430c-8123-a290107db020.png](attachment:33be923c-452b-42e8-9793-d9ad6b526a36.png)

# %% [markdown]
# ![image-7c2af2d8-b72a-44b9-9eb0-6a46a1a78818.png](attachment:821cfe43-3b7b-42a2-9536-9deb63b67954.png)
