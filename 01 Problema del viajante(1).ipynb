# %% [markdown]
# # Problema del viajante

# %% [markdown]
# Crédito al profesor **Fernando Ignacio Becerra López**. Actividad adaptada de su curso IDI1.

# %% [markdown]
# ## Planteamiento

# %% [markdown]
# Eres un agente de viajes / alguien que quiere viajar, y tienes una lista de ciudades destino. Quieres planear una ruta cíclica que visite todas las ciudades, pero quieres optimizar o tiempo de viaje o costos de viaje (o una combinación de ambas).
#
# ¿Cuál es el mejor orden para visitar todas estas ciudades?

# %% [markdown]
# 1. Toma el archivo `datosCT.xlsx` y lee la hoja `8c` utilizando `pandas`.
#
# `nombre_de_variable = pd.read_excel("datosCT.xlsx", sheet_name="8c").set_index("Unnamed: 0")`
#
# Imprime la tabla resultante.

# %%
import pandas as pd
import numpy as np

df = pd.read_excel("datosCT.xlsx", sheet_name="8c").set_index("Unnamed: 0")
df
# Out:
#             Tijuana  Mérida   GDL  México  León  Monterrey  Tapachula  \
# Unnamed: 0
# Tijuana           0    4180  2306    2848  2529       2409       4005
# Mérida         4180       0  1874    1332  1719       2046       1062
# GDL            2306    1874     0     542   223        789       1699
# México         2848    1332   542       0   389        933       1157
# León           2529    1719   223     389     0        711       1544
# Monterrey      2409    2046   789     933   711          0       1803
# Tapachula      4005    1062  1699    1157  1544       1803          0
# Chihuahua      1583    2819  1202    1487  1140        826       2644
#
#             Chihuahua
# Unnamed: 0
# Tijuana          1583
# Mérida           2819
# GDL              1202
# México           1487
# León             1140
# Monterrey         826
# Tapachula        2644
# Chihuahua           0

# %% [markdown]
# La tabla contiene una matriz de la distancia de recorrido entre cada ciudad. Por ejemplo, si quiero saber la distancia entre Tijuana y Tapachula busco el renglón Tijuana y la columna Tapachula / la columna Tijuana y el renglón Tapachula.
#
# 2. Crea una función que retorne las ciudades de la tabla en un orden aleatorio.

# %%
import random

def generar_ruta_aleatoria(df):
    ciudades = list(df.columns)
    ciudades_aleatorias = random.sample(ciudades, len(ciudades))

    return ciudades_aleatorias

ruta = generar_ruta_aleatoria(df)

ruta
# Out:
# ['GDL',
#  'León',
#  'Monterrey',
#  'Tijuana',
#  'México',
#  'Chihuahua',
#  'Tapachula',
#  'Mérida']

# %% [markdown]
# 3. Crea una función que dadas dos ciudades te indique la distancia entre ellas.

# %%
def obtener_distancia(ciudad1, ciudad2, df):
    if ciudad1 not in df.index or ciudad2 not in df.columns:
        return None

    distancia = df.loc[ciudad1, ciudad2]

    return distancia

ciudad1 = "Tijuana"
ciudad2 = "Tapachula"

distancia = obtener_distancia(ciudad1, ciudad2, df)

distancia
# Out:
# 4005

# %% [markdown]
# 4. Crea una función que calcule la distancia total de recorrer una lista de ciudades:
#     - $C1 → C2 + C2 → C3 + ... + C_{n-1} → C_n + C_n → C_1$

# %%
def calcular_distancia_total(ciudades, df):
    distancia_total = 0
    for i in range(len(ciudades) - 1):
        ciudad_actual = ciudades[i]
        ciudad_siguiente = ciudades[i + 1]
        distancia_total += df.loc[ciudad_actual, ciudad_siguiente]

    distancia_total += df.loc[ciudades[-1], ciudades[0]]

    return distancia_total

ciudades = ruta

distancia_total = calcular_distancia_total(ciudades, df)

distancia_total
# Out:
# 13258

# %% [markdown]
# 5. Genera una lista con 100 listas de ciudades generadas con permutaciones aleatorias (no importa si hay repetidas)

# %%
import random

def generar_permutaciones_aleatorias(ciudades, num_permutaciones):
    permutaciones = []

    for _ in range(num_permutaciones):
        random.shuffle(ciudades)
        permutaciones.append(ciudades)

    return permutaciones

ciudades = ruta

permutaciones_aleatorias = generar_permutaciones_aleatorias(ciudades, 100)

permutaciones_aleatorias
# Out:
# [['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana'],
#  ['GDL',
#   'México',
#   'León',
#   'Chihuahua',
#   'Monterrey',
#   'Tapachula',
#   'Mérida',
#   'Tijuana']]

# %% [markdown]
# 6. Calcula la distancia total de todas las rutas generadas y guarda la información en otra lista.

# %%
distancias_totales = []

for perm in permutaciones_aleatorias:
    distancia_total = calcular_distancia_total(perm, df)
    distancias_totales.append(distancia_total)

distancias_totales
# Out:
# [12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248,
#  12248]

# %% [markdown]
# 7. ¿Cuál fue la mejor ruta? Compara con tus compañeros

# %% [markdown]
# ## ¿Qué hay detrás?

# %% [markdown]
# Hasta ahora, las optimizaciones que hemos hecho en clase han sido todas de funciones convexas, que garantizan un mínimo/máximo global. Incluso en los casos de regresiones o programación lineal, que teníamos muchas variables y graficarlas era imposible, se sabe desde el planteamiento del problema que la solución será única.
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTWjD1olGFjjZN8Yi99lqDzWa1X5Rz4b4BP7g&s)

# %% [markdown]
# Estos casos y campo de estudio se conocen como **Optimización Convexa**. Hay casos en los que el problema se puede adaptar para suavizar su respuesta y *volverlo* convexo, pero en muchos casos las funciones no son convexas y resultan en la aparición de muchos mínimos y máximos.
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTsUVelChbZG6NX2cHTB68j3Ma0_8RUKnPUNg&s)

# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/e/e3/Non-Convex_Objective_Function.gif)

# %% [markdown]
# En los casos donde podemos graficar es muy sencillo saber si el valor óptimo encontrado es global o no, pero una solución general para *n* dimensiones en un problema no existe. Imaginemos el cerebro humano aprendiendo un deporte sin instructor:
# - Alguien puede aprender a jugar tennis **sin** instructor, viendo y replicando comportamientos y patrones vistos anteriormente (aprendiendo)
# - Alguien también puede aprender a jugar tennis **con** instructor, donde el instructor corregirá hábitos erróneos.

# %% [markdown]
# Por lógica, la persona que está aprendiendo sin instructor llegará a un nivel de juego donde sus limitantes serán los malos hábitos formados al aprender y optimizar su forma de juego (óptimo local).
#
# La persona con instructor será guiada a un mínimo global pues el instructor conoce su ubicación.

# %% [markdown]
# Todos aprendemos de formas diferentes y cada quién podría llegar a su óptimo en dado tiempo; no hay garantía de que la forma en la que aprendes sea la mejor, entonces lo mejor es tener una mente abierta para ver si es que te has estancado y quizás hay otro valor óptimo en alguna otra parte.

# %% [markdown]
# ## Uniendo

# %% [markdown]
# En el caso del problema de las ciudades hay 20,160 posibles combinaciones (excluyendo rutas repetidas con el viaje en orden reverso). Con las computadoras de hoy en día podemos revisar todos esos casos y tomar el mejor. ¿Qué pasa si añadimos ciudades?
# - 9 ciudades → $181,440$ combinaciones
# - 10 ciudades → $1'814,400$ combinaciones
# - 15 ciudades → $653,837'184,000$ combinaciones
#
# Para 15 ciudades, si cada ruta distinta nos tomara 1 segundo procesarla, se tardaría ~21 años en calcular todos los casos posibles. Si agregamos otra ciudad, entonces serían ~335 años.

# %% [markdown]
# Los algoritmos de optimización con métodos numéricos necesitan un punto de partida, y a partir de ahí iteran hasta encontrar un mínimo/máximo sin poder saber si es local o global. ¿Cómo sabemos cuántas veces intentar optimizar y con qué punto de partida si no sabemos cuántos mínimos/máximos existen en nuestro problema o si siquiera existe un mínimo/máximo global?

# %% [markdown]
# **No sabemos.** Lo mejor que podemos hacer es usar *métodos de búsqueda* / *algoritmos probabilísticos* para intentar encontrar la mejor solución posible en el momento y decidir si esa solución es suficiente.

# %% [markdown]
# ## Siguientes pasos

# %% [markdown]
# En lugar de usar fuerza bruta (Monte Carlo o algoritmos iterativos) para encontrar la respuesta empezaremos a usar búsquedas dirigidas para intentar mejorar nuestros resultados mientras diminuimos nuestro tiempo de procesamiento.
